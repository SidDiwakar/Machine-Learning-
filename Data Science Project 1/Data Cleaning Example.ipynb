# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen
# %matplotlib inline

# %%
df = pd.read_csv("D:\Data Science\iris data set\sat_act_analysis-master\sat_act_2017_2018.csv")
df
# Out:
#                    state  sat_participation_17  sat_score_17  \
# 0                Alabama                   5.0        1165.0
# 1                 Alaska                  38.0        1080.0
# 2                Arizona                  30.0        1116.0
# 3               Arkansas                   3.0        1208.0
# 4             California                  53.0        1055.0
# 5               Colorado                  11.0        1201.0
# 6            Connecticut                 100.0        1041.0
# 7               Delaware                 100.0         996.0
# 8   District of Columbia                 100.0         950.0
# 9                Florida                  83.0        1017.0
# 10               Georgia                  61.0        1050.0
# 11                Hawaii                  55.0        1085.0
# 12                 Idaho                  93.0        1005.0
# 13              Illinois                   9.0        1115.0
# ...

# %%
df.shape
# Out:
# (51, 9)

# %%
df.head()
# Out:
#         state  sat_participation_17  sat_score_17  act_participation_17  \
# 0     Alabama                   5.0        1165.0                 100.0
# 1      Alaska                  38.0        1080.0                  65.0
# 2     Arizona                  30.0        1116.0                  62.0
# 3    Arkansas                   3.0        1208.0                 100.0
# 4  California                  53.0        1055.0                  31.0
#
#    act_composite_17  sat_participation_18  sat_score_18  act_participation_18  \
# 0              19.2                   6.0        1166.0                 100.0
# 1              19.8                  43.0        1106.0                  33.0
# 2              19.7                  29.0        1149.0                  66.0
# 3              19.4                   5.0        1169.0                 100.0
# 4              22.8                  60.0        1076.0                  27.0
#
#    act_composite_18
# 0              19.1
# 1              20.8
# ...

# %%
df.boxplot(column='sat_participation_18')

# %%
df.lookup['sat_participation_18']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-53fa603cf912> in <module>()
# ----> 1 df.lookup['sat_participation_18']
#
# TypeError: 'method' object is not subscriptable
